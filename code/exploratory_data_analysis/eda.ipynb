# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_train = pd.read_parquet('../../data/model_data/training_data.parquet').sort_values(by=['Date', 'Ticker'], ignore_index=True)

df_train
# Out:
#                            Date Ticker  Adj Close in 60 Days   Adj Close  \
# 0     2015-12-24 00:00:00+00:00   AAPL             24.194263   24.494490
# 1     2015-12-24 00:00:00+00:00    CAT             59.485294   55.321060
# 2     2015-12-24 00:00:00+00:00    CVX             65.311241   63.431988
# 3     2015-12-24 00:00:00+00:00     GS            129.326538  152.492950
# 4     2015-12-24 00:00:00+00:00     HD            106.316124  107.910774
# ...                         ...    ...                   ...         ...
# 29140 2024-07-03 00:00:00+00:00    MRK            113.690002  125.013603
# 29141 2024-07-03 00:00:00+00:00   MSFT            428.019989  459.940979
# 29142 2024-07-03 00:00:00+00:00    UNH            581.849976  488.159027
# 29143 2024-07-03 00:00:00+00:00    WBA              9.060000   10.841380
# 29144 2024-07-03 00:00:00+00:00    WMT             79.779999   68.046036
#
#            Volume  10 Day Change  10 Day Gain  10 Day Loss  10 Day Avg Gain  \
# ...

# %%
df_train['Target'] = df_train['Adj Close in 60 Days'] - df_train['Adj Close']

df_train
# Out:
#                            Date Ticker  Adj Close in 60 Days   Adj Close  \
# 0     2015-12-24 00:00:00+00:00   AAPL             24.194263   24.494490
# 1     2015-12-24 00:00:00+00:00    CAT             59.485294   55.321060
# 2     2015-12-24 00:00:00+00:00    CVX             65.311241   63.431988
# 3     2015-12-24 00:00:00+00:00     GS            129.326538  152.492950
# 4     2015-12-24 00:00:00+00:00     HD            106.316124  107.910774
# ...                         ...    ...                   ...         ...
# 29140 2024-07-03 00:00:00+00:00    MRK            113.690002  125.013603
# 29141 2024-07-03 00:00:00+00:00   MSFT            428.019989  459.940979
# 29142 2024-07-03 00:00:00+00:00    UNH            581.849976  488.159027
# 29143 2024-07-03 00:00:00+00:00    WBA              9.060000   10.841380
# 29144 2024-07-03 00:00:00+00:00    WMT             79.779999   68.046036
#
#            Volume  10 Day Change  10 Day Gain  10 Day Loss  10 Day Avg Gain  \
# ...

# %%
df_train.describe()
# Out:
#        Adj Close in 60 Days     Adj Close        Volume  10 Day Change  \
# count          29145.000000  29145.000000  2.914500e+04   29145.000000
# mean             134.804276    129.887164  1.908109e+07       0.075851
# std              109.563565    105.122715  3.238278e+07       2.664496
# min                8.250000     10.841380  4.601000e+05     -44.027237
# 25%               49.882431     49.087166  4.125000e+06      -0.634842
# 50%              103.437691     98.824692  7.856800e+06       0.046055
# 75%              176.459839    169.821014  1.949730e+07       0.800396
# max              602.045166    544.675720  5.334788e+08      31.809906
#
#         10 Day Gain   10 Day Loss  10 Day Avg Gain  10 Day Avg Loss  \
# count  29145.000000  29145.000000     29145.000000     29145.000000
# mean       0.782533      0.706682         0.780819         0.705081
# std        1.724967      1.737235         0.841151         0.858526
# ...

# %%
df_train.corr(numeric_only=True)[['Adj Close in 60 Days', 'Target']].sort_values(by=['Target'], ascending=False)
# Out:
#                                                Adj Close in 60 Days    Target
# Target                                                     0.318477  1.000000
# Adj Close in 60 Days                                       1.000000  0.318477
# 60 Day Avg Loss                                            0.796059  0.210023
# 10 Day Avg Loss                                            0.623636  0.208558
# 30 Day Avg Loss                                            0.737482  0.207054
# 60 Day Avg Gain                                            0.882004  0.171676
# 30 Day Avg Gain                                            0.841307  0.169617
# Adj Close Mean 40 to 50 Day Lag                            0.977871  0.169123
# 60 Day Price 90th Percentile                               0.983438  0.167547
# Adj Close Mean 30 to 40 Day Lag                            0.979457  0.165761
# 60 Day Price Mean                                          0.982901  0.165533
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df_train.assign(f=pd.cut(df_train['Congressional Sales Past 90 Calendar Days'], bins=[0, 1, 5, 10, 15, 20, 50])),
    x='f',
    y='Target'
)

plt.ylim(-100, 100)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df_train.assign(f=pd.cut(df_train['Congressional Sales Past 90 Calendar Days'], bins=[0, 1, 5, 10, 15, 20, 50])),
    x='f',
    y='Target'
)

plt.ylim(-100, 100)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_train,
    x='Adj Close Mean 0 to 10 Day Lag Difference',
    y='Target',
    alpha=0.10,
)

plt.ylim(-100, 100)

plt.show()
