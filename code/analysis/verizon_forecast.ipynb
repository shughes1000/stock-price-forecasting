# %% [markdown]
# ### Load Data

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_test = pd.read_parquet('../../data/model_data/testing_data.parquet').sort_values(by=['Date', 'Ticker'], ignore_index=True)

df_test
# Out:
#                            Date Ticker  Adj Close in 60 Days   Adj Close  \
# 0     2015-12-24 00:00:00+00:00   AMGN            115.816658  126.452103
# 1     2015-12-24 00:00:00+00:00     BA            120.255928  128.722504
# 2     2015-12-24 00:00:00+00:00    CRM             71.462753   77.486023
# 3     2015-12-24 00:00:00+00:00    MMM            101.896019   93.109833
# 4     2015-12-24 00:00:00+00:00     PG             65.515038   62.572762
# ...                         ...    ...                   ...         ...
# 17147 2024-07-03 00:00:00+00:00    MMM            137.300003  101.075127
# 17148 2024-07-03 00:00:00+00:00     PG            173.550003  162.850555
# 17149 2024-07-03 00:00:00+00:00    TRV            236.110001  202.802933
# 17150 2024-07-03 00:00:00+00:00      V            275.170013  268.451660
# 17151 2024-07-03 00:00:00+00:00     VZ             44.200008   39.836033
#
#           Volume  10 Day Avg Gain  10 Day Avg Loss  30 Day Avg Gain  \
# 0       943000.0         1.096357         0.796363         1.006924
# 1      1185000.0         0.860066         1.118356         0.722253
# 2      1084700.0         0.301661         0.455975         0.410512
# 3      1014686.0         0.547489         0.937321         0.418124
# 4      2498000.0         0.392109         0.235263         0.312118
# ...          ...              ...              ...              ...
# 17147  1230800.0         0.492346         0.407801         0.398187
# 17148  2980500.0         0.254468         0.724640         0.502974
# 17149   523100.0         0.665091         1.144991         0.749383
# 17150  5017800.0         1.084824         1.546899         0.893207
# 17151  6653900.0         0.196661         0.095909         0.186651
#
#        30 Day Avg Loss  60 Day Avg Gain  60 Day Avg Loss  60 Day Price Std  \
# 0             0.814146         1.009135         0.699529          4.877767
# 1             0.765898         0.755481         0.550366          4.418714
# 2             0.439715         0.442038         0.360400          1.959126
# 3             0.558164         0.471638         0.355560          3.042756
# 4             0.211999         0.276281         0.165433          1.708618
# ...                ...              ...              ...               ...
# 17147         0.493153         0.534609         0.363463          4.311441
# 17148         0.618281         0.546859         0.401216          4.032108
# 17149         1.109372         0.799882         1.227396          4.858594
# 17150         1.210904         0.873464         1.010804          4.046228
# 17151         0.154358         0.170989         0.170101          0.713149
#
#        60 Day Price Mean  60 Day Price 10th Percentile  \
# 0             120.935859                    113.872980
# 1             128.754730                    122.425815
# 2              77.697573                     74.935341
# 3              94.410902                     90.543301
# 4              59.624889                     57.670639
# ...                  ...                           ...
# 17147          97.311003                     90.673070
# 17148         162.986984                    155.269542
# 17149         211.269899                    204.942570
# 17150         272.651303                    267.565256
# 17151          38.898097                     38.073831
#
#        60 Day Price 90th Percentile  Adj Close Mean 0 to 10 Day Lag  \
# 0                        125.740771                      124.367628
# 1                        132.987834                      128.988866
# 2                         80.333372                       77.316764
# 3                         97.323853                       92.691669
# 4                         61.964988                       62.221431
# ...                             ...                             ...
# 17147                    101.844837                      101.428220
# 17148                    166.811732                      165.074182
# 17149                    217.742920                      205.892415
# 17150                    277.995547                      269.957657
# 17151                     39.867035                       39.697499
#
#        Adj Close Mean 10 to 20 Day Lag  Adj Close Mean 20 to 30 Day Lag  \
# 0                           123.584390                       122.481847
# 1                           131.408534                       131.562788
# 2                            80.091447                        78.447742
# 3                            96.557341                        96.801584
# 4                            60.184812                        59.228064
# ...                                ...                              ...
# 17147                        99.968090                        99.001164
# 17148                       166.086095                       164.065250
# 17149                       207.809865                       210.726520
# 17150                       273.140280                       272.119324
# 17151                        39.061982                        38.853695
#
#        Adj Close Mean 30 to 40 Day Lag  Adj Close Mean 40 to 50 Day Lag  \
# 0                           123.234310                       119.349458
# 1                           131.684204                       127.417228
# 2                            78.189886                        77.475058
# 3                            96.959827                        93.484661
# 4                            59.851521                        59.040537
# ...                                ...                              ...
# 17147                        99.215373                        93.435883
# 17148                       165.471790                       161.920151
# 17149                       215.512764                       211.772733
# 17150                       278.085852                       270.490982
# 17151                        38.841101                        38.171677
#
#        Adj Close Mean 0 to 10 Day Lag Difference  \
# 0                                       0.783237
# 1                                      -2.419669
# 2                                      -2.774683
# 3                                      -3.865672
# 4                                       2.036619
# ...                                          ...
# 17147                                   1.460130
# 17148                                  -1.011913
# 17149                                  -1.917450
# 17150                                  -3.182623
# 17151                                   0.635518
#
#        Adj Close Mean 10 to 20 Day Lag Difference  \
# 0                                        1.102544
# 1                                       -0.154253
# 2                                        1.643704
# 3                                       -0.244243
# 4                                        0.956747
# ...                                           ...
# 17147                                    0.966926
# 17148                                    2.020845
# 17149                                   -2.916655
# 17150                                    1.020956
# 17151                                    0.208287
#
#        Adj Close Mean 20 to 30 Day Lag Difference  \
# 0                                       -0.752464
# 1                                       -0.121416
# 2                                        0.257856
# 3                                       -0.158244
# 4                                       -0.623456
# ...                                           ...
# 17147                                   -0.214209
# 17148                                   -1.406540
# 17149                                   -4.786244
# 17150                                   -5.966528
# 17151                                    0.012594
#
#        Adj Close Mean 30 to 40 Day Lag Difference  \
# 0                                        3.884852
# 1                                        4.266976
# 2                                        0.714828
# 3                                        3.475166
# 4                                        0.810983
# ...                                           ...
# 17147                                    5.779490
# 17148                                    3.551639
# 17149                                    3.740031
# 17150                                    7.594870
# 17151                                    0.669424
#
#        Volume Mean 0 to 10 Day Lag  Volume Mean 10 to 20 Day Lag  \
# 0                        3509140.0                     2935060.0
# 1                        4102880.0                     3429540.0
# 2                        3380550.0                     3321140.0
# 3                        4314270.8                     2702302.2
# 4                       11361240.0                     8779930.0
# ...                            ...                           ...
# 17147                    3857360.0                     3596170.0
# 17148                    7454720.0                     5010550.0
# 17149                    1482260.0                     1208760.0
# 17150                   12733170.0                     6560590.0
# 17151                   19543700.0                    13718620.0
#
#        Volume Mean 20 to 30 Day Lag  Volume Mean 30 to 40 Day Lag  \
# 0                         3244410.0                     3121370.0
# 1                         2874360.0                     2669230.0
# 2                         4858610.0                     2680950.0
# 3                         2377576.3                     2735491.2
# 4                         7697420.0                     7611840.0
# ...                             ...                           ...
# 17147                     5981670.0                     4513980.0
# 17148                     5626180.0                     5269990.0
# 17149                     1186330.0                      952710.0
# 17150                     5575850.0                    10566510.0
# 17151                    18323040.0                    14234740.0
#
#        Volume Mean 40 to 50 Day Lag  \
# 0                         3939210.0
# 1                         4932430.0
# 2                         3133940.0
# 3                         3282111.0
# 4                        10391110.0
# ...                             ...
# 17147                     6318350.0
# 17148                     6465080.0
# 17149                     1215390.0
# 17150                     5965770.0
# 17151                    17835740.0
#
#        Congressional Purchases Past 90 Calendar Days  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  5
# ...                                              ...
# 17147                                              0
# 17148                                              1
# 17149                                              0
# 17150                                              1
# 17151                                              0
#
#        Congressional Sales Past 90 Calendar Days  Unemployment Rate  DSG10  \
# 0                                              1                5.0   2.25
# 1                                              0                5.0   2.25
# 2                                              0                5.0   2.25
# 3                                              4                5.0   2.25
# 4                                              0                5.0   2.25
# ...                                          ...                ...    ...
# 17147                                          1                4.3   4.36
# 17148                                          2                4.3   4.36
# 17149                                          0                4.3   4.36
# 17150                                          2                4.3   4.36
# 17151                                          1                4.3   4.36
#
#              GDP
# 0      18435.137
# 1      18435.137
# 2      18435.137
# 3      18435.137
# 4      18435.137
# ...          ...
# 17147  29349.924
# 17148  29349.924
# 17149  29349.924
# 17150  29349.924
# 17151  29349.924
#
# [17152 rows x 34 columns]

# %%
df_test.drop(
    columns=[
        'Volume', '10 Day Avg Gain', '30 Day Avg Gain', '60 Day Price Std',
        '60 Day Price Mean', 'Adj Close Mean 30 to 40 Day Lag',
        'Adj Close Mean 10 to 20 Day Lag Difference',
        'Adj Close Mean 20 to 30 Day Lag Difference',
        'Adj Close Mean 30 to 40 Day Lag Difference',
        'Volume Mean 0 to 10 Day Lag', 'Volume Mean 20 to 30 Day Lag',
        'Volume Mean 30 to 40 Day Lag', 'Volume Mean 40 to 50 Day Lag',
        'Congressional Purchases Past 90 Calendar Days',

        'Adj Close Mean 10 to 20 Day Lag',
        'Adj Close Mean 40 to 50 Day Lag', 'Volume Mean 10 to 20 Day Lag',
    ],
    inplace=True,
)

df_test.shape
# Out:
# (17152, 17)

# %%
df_test = df_test.loc[df_test['Ticker'] == 'VZ', :].reset_index(drop=True)

df_test
# Out:
#                           Date Ticker  Adj Close in 60 Days  Adj Close  \
# 0    2015-12-24 00:00:00+00:00     VZ             33.974438  29.628868
# 1    2015-12-28 00:00:00+00:00     VZ             34.391811  29.654245
# 2    2015-12-29 00:00:00+00:00     VZ             34.289070  29.946028
# 3    2015-12-30 00:00:00+00:00     VZ             34.706451  29.666933
# 4    2015-12-31 00:00:00+00:00     VZ             34.700027  29.318052
# ...                        ...    ...                   ...        ...
# 2139 2024-06-27 00:00:00+00:00     VZ             43.579693  39.545399
# 2140 2024-06-28 00:00:00+00:00     VZ             43.973545  39.952290
# 2141 2024-07-01 00:00:00+00:00     VZ             43.865234  40.436676
# 2142 2024-07-02 00:00:00+00:00     VZ             43.934158  39.816658
# 2143 2024-07-03 00:00:00+00:00     VZ             44.200008  39.836033
#
#       10 Day Avg Loss  30 Day Avg Loss  60 Day Avg Gain  60 Day Avg Loss  \
# 0            0.107198         0.117982         0.136688         0.091219
# 1            0.075483         0.107622         0.137111         0.091219
# 2            0.075483         0.094935         0.141974         0.089967
# 3            0.103393         0.104238         0.129868         0.094618
# 4            0.138281         0.115868         0.129242         0.100433
# ...               ...              ...              ...              ...
# 2139         0.064908         0.147577         0.160578         0.177404
# 2140         0.064908         0.147577         0.162593         0.177404
# 2141         0.054251         0.139827         0.170666         0.171207
# 2142         0.095909         0.154358         0.170666         0.176298
# 2143         0.095909         0.154358         0.170989         0.170101
#
#       60 Day Price 10th Percentile  60 Day Price 90th Percentile  \
# 0                        28.000587                     29.465856
# 1                        28.051327                     29.484884
# 2                        28.055767                     29.514686
# 3                        28.095721                     29.631406
# 4                        28.134421                     29.631406
# ...                            ...                           ...
# 2139                     38.073831                     39.899973
# 2140                     38.073831                     39.891254
# 2141                     38.073831                     39.891254
# 2142                     38.073831                     39.867035
# 2143                     38.073831                     39.867035
#
#       Adj Close Mean 0 to 10 Day Lag  Adj Close Mean 20 to 30 Day Lag  \
# 0                          29.171529                        28.595571
# 1                          29.293952                        28.620942
# 2                          29.405591                        28.698330
# 3                          29.482978                        28.732582
# 4                          29.464583                        28.722431
# ...                              ...                              ...
# 2139                       39.095889                        38.553374
# 2140                       39.237331                        38.537874
# 2141                       39.437868                        38.625064
# 2142                       39.596747                        38.714191
# 2143                       39.697499                        38.853695
#
#       Adj Close Mean 0 to 10 Day Lag Difference  \
# 0                                      0.380591
# 1                                      0.529020
# 2                                      0.640659
# 3                                      0.719950
# 4                                      0.600698
# ...                                         ...
# 2139                                  -0.453386
# 2140                                  -0.258661
# 2141                                   0.085254
# 2142                                   0.391387
# 2143                                   0.635518
#
#       Congressional Sales Past 90 Calendar Days  Unemployment Rate  DSG10  \
# 0                                             1                5.0   2.25
# 1                                             1                5.0   2.24
# 2                                             1                5.0   2.32
# 3                                             1                5.0   2.31
# 4                                             1                5.0   2.27
# ...                                         ...                ...    ...
# 2139                                          1                4.1   4.29
# 2140                                          1                4.1   4.36
# 2141                                          1                4.3   4.48
# 2142                                          1                4.3   4.43
# 2143                                          1                4.3   4.36
#
#             GDP
# 0     18435.137
# 1     18435.137
# 2     18435.137
# 3     18435.137
# 4     18435.137
# ...         ...
# 2139  29016.714
# 2140  29016.714
# 2141  29349.924
# 2142  29349.924
# 2143  29349.924
#
# [2144 rows x 17 columns]

# %% [markdown]
# ### Load Models

# %%
import pickle

with open('../../data/models/lightgbm.pkl', 'rb') as f:
    mod = pickle.load(f)

mod
# Out:
# LGBMRegressor(early_stopping_round=25, feature_fraction=0.36447380800372364,
#               lambda_l1=8.509181190110327, lambda_l2=6.945205814868604,
#               max_depth=9, metric='mean_absolute_error', min_child_samples=90,
#               n_estimators=500, num_leaves=222, random_state=22, verbosity=-1)

# %%
with open('../../data/models/lightgbm_lower_bound.pkl', 'rb') as f:
    mod_lower = pickle.load(f)

mod_lower
# Out:
# LGBMRegressor(alpha=0.1, early_stopping_round=25,
#               feature_fraction=0.8823837495037814, lambda_l1=8.100702494769967,
#               lambda_l2=1.7182127368382263, max_depth=12, metric='quantile',
#               min_child_samples=98, n_estimators=500, num_leaves=7,
#               objective='quantile', random_state=22, verbosity=-1)

# %%
with open('../../data/models/lightgbm_upper_bound.pkl', 'rb') as f:
    mod_upper = pickle.load(f)

mod_upper
# Out:
# LGBMRegressor(alpha=0.9, early_stopping_round=25,
#               feature_fraction=0.05162746463216121, lambda_l1=4.794130716175195,
#               lambda_l2=8.043177998295917, max_depth=3, metric='quantile',
#               min_child_samples=22, n_estimators=500, num_leaves=37,
#               objective='quantile', random_state=22, verbosity=-1)

# %%
X_test = df_test.drop(columns=['Date', 'Ticker', 'Adj Close in 60 Days'])

X_test
# Out:
#       Adj Close  10 Day Avg Loss  30 Day Avg Loss  60 Day Avg Gain  \
# 0     29.628868         0.107198         0.117982         0.136688
# 1     29.654245         0.075483         0.107622         0.137111
# 2     29.946028         0.075483         0.094935         0.141974
# 3     29.666933         0.103393         0.104238         0.129868
# 4     29.318052         0.138281         0.115868         0.129242
# ...         ...              ...              ...              ...
# 2139  39.545399         0.064908         0.147577         0.160578
# 2140  39.952290         0.064908         0.147577         0.162593
# 2141  40.436676         0.054251         0.139827         0.170666
# 2142  39.816658         0.095909         0.154358         0.170666
# 2143  39.836033         0.095909         0.154358         0.170989
#
#       60 Day Avg Loss  60 Day Price 10th Percentile  \
# 0            0.091219                     28.000587
# 1            0.091219                     28.051327
# 2            0.089967                     28.055767
# 3            0.094618                     28.095721
# 4            0.100433                     28.134421
# ...               ...                           ...
# 2139         0.177404                     38.073831
# 2140         0.177404                     38.073831
# 2141         0.171207                     38.073831
# 2142         0.176298                     38.073831
# 2143         0.170101                     38.073831
#
#       60 Day Price 90th Percentile  Adj Close Mean 0 to 10 Day Lag  \
# 0                        29.465856                       29.171529
# 1                        29.484884                       29.293952
# 2                        29.514686                       29.405591
# 3                        29.631406                       29.482978
# 4                        29.631406                       29.464583
# ...                            ...                             ...
# 2139                     39.899973                       39.095889
# 2140                     39.891254                       39.237331
# 2141                     39.891254                       39.437868
# 2142                     39.867035                       39.596747
# 2143                     39.867035                       39.697499
#
#       Adj Close Mean 20 to 30 Day Lag  \
# 0                           28.595571
# 1                           28.620942
# 2                           28.698330
# 3                           28.732582
# 4                           28.722431
# ...                               ...
# 2139                        38.553374
# 2140                        38.537874
# 2141                        38.625064
# 2142                        38.714191
# 2143                        38.853695
#
#       Adj Close Mean 0 to 10 Day Lag Difference  \
# 0                                      0.380591
# 1                                      0.529020
# 2                                      0.640659
# 3                                      0.719950
# 4                                      0.600698
# ...                                         ...
# 2139                                  -0.453386
# 2140                                  -0.258661
# 2141                                   0.085254
# 2142                                   0.391387
# 2143                                   0.635518
#
#       Congressional Sales Past 90 Calendar Days  Unemployment Rate  DSG10  \
# 0                                             1                5.0   2.25
# 1                                             1                5.0   2.24
# 2                                             1                5.0   2.32
# 3                                             1                5.0   2.31
# 4                                             1                5.0   2.27
# ...                                         ...                ...    ...
# 2139                                          1                4.1   4.29
# 2140                                          1                4.1   4.36
# 2141                                          1                4.3   4.48
# 2142                                          1                4.3   4.43
# 2143                                          1                4.3   4.36
#
#             GDP
# 0     18435.137
# 1     18435.137
# 2     18435.137
# 3     18435.137
# 4     18435.137
# ...         ...
# 2139  29016.714
# 2140  29016.714
# 2141  29349.924
# 2142  29349.924
# 2143  29349.924
#
# [2144 rows x 14 columns]

# %%
df_test['Prediction'] = mod.predict(X_test) + df_test['Adj Close']
df_test['Lower Bound Prediction'] = mod_lower.predict(X_test) + df_test['Adj Close']
df_test['Upper Bound Prediction'] = mod_upper.predict(X_test) + df_test['Adj Close']

df_test
# Out:
#                           Date Ticker  Adj Close in 60 Days  Adj Close  \
# 0    2015-12-24 00:00:00+00:00     VZ             33.974438  29.628868
# 1    2015-12-28 00:00:00+00:00     VZ             34.391811  29.654245
# 2    2015-12-29 00:00:00+00:00     VZ             34.289070  29.946028
# 3    2015-12-30 00:00:00+00:00     VZ             34.706451  29.666933
# 4    2015-12-31 00:00:00+00:00     VZ             34.700027  29.318052
# ...                        ...    ...                   ...        ...
# 2139 2024-06-27 00:00:00+00:00     VZ             43.579693  39.545399
# 2140 2024-06-28 00:00:00+00:00     VZ             43.973545  39.952290
# 2141 2024-07-01 00:00:00+00:00     VZ             43.865234  40.436676
# 2142 2024-07-02 00:00:00+00:00     VZ             43.934158  39.816658
# 2143 2024-07-03 00:00:00+00:00     VZ             44.200008  39.836033
#
#       10 Day Avg Loss  30 Day Avg Loss  60 Day Avg Gain  60 Day Avg Loss  \
# 0            0.107198         0.117982         0.136688         0.091219
# 1            0.075483         0.107622         0.137111         0.091219
# 2            0.075483         0.094935         0.141974         0.089967
# 3            0.103393         0.104238         0.129868         0.094618
# 4            0.138281         0.115868         0.129242         0.100433
# ...               ...              ...              ...              ...
# 2139         0.064908         0.147577         0.160578         0.177404
# 2140         0.064908         0.147577         0.162593         0.177404
# 2141         0.054251         0.139827         0.170666         0.171207
# 2142         0.095909         0.154358         0.170666         0.176298
# 2143         0.095909         0.154358         0.170989         0.170101
#
#       60 Day Price 10th Percentile  60 Day Price 90th Percentile  \
# 0                        28.000587                     29.465856
# 1                        28.051327                     29.484884
# 2                        28.055767                     29.514686
# 3                        28.095721                     29.631406
# 4                        28.134421                     29.631406
# ...                            ...                           ...
# 2139                     38.073831                     39.899973
# 2140                     38.073831                     39.891254
# 2141                     38.073831                     39.891254
# 2142                     38.073831                     39.867035
# 2143                     38.073831                     39.867035
#
#       Adj Close Mean 0 to 10 Day Lag  Adj Close Mean 20 to 30 Day Lag  \
# 0                          29.171529                        28.595571
# 1                          29.293952                        28.620942
# 2                          29.405591                        28.698330
# 3                          29.482978                        28.732582
# 4                          29.464583                        28.722431
# ...                              ...                              ...
# 2139                       39.095889                        38.553374
# 2140                       39.237331                        38.537874
# 2141                       39.437868                        38.625064
# 2142                       39.596747                        38.714191
# 2143                       39.697499                        38.853695
#
#       Adj Close Mean 0 to 10 Day Lag Difference  \
# 0                                      0.380591
# 1                                      0.529020
# 2                                      0.640659
# 3                                      0.719950
# 4                                      0.600698
# ...                                         ...
# 2139                                  -0.453386
# 2140                                  -0.258661
# 2141                                   0.085254
# 2142                                   0.391387
# 2143                                   0.635518
#
#       Congressional Sales Past 90 Calendar Days  Unemployment Rate  DSG10  \
# 0                                             1                5.0   2.25
# 1                                             1                5.0   2.24
# 2                                             1                5.0   2.32
# 3                                             1                5.0   2.31
# 4                                             1                5.0   2.27
# ...                                         ...                ...    ...
# 2139                                          1                4.1   4.29
# 2140                                          1                4.1   4.36
# 2141                                          1                4.3   4.48
# 2142                                          1                4.3   4.43
# 2143                                          1                4.3   4.36
#
#             GDP  Prediction  Lower Bound Prediction  Upper Bound Prediction
# 0     18435.137   31.585284               28.648794               33.685207
# 1     18435.137   31.610661               28.674171               34.607806
# 2     18435.137   31.902443               28.965953               34.582874
# 3     18435.137   31.623349               28.888461               34.806889
# 4     18435.137   31.274468               28.539580               34.272690
# ...         ...         ...                     ...                     ...
# 2139  29016.714   39.641537               32.943688               47.088453
# 2140  29016.714   39.737711               33.350579               47.480432
# 2141  29349.924   41.524728               35.234835               50.041584
# 2142  29349.924   40.724780               34.325812               49.635444
# 2143  29349.924   40.744155               34.345186               49.365829
#
# [2144 rows x 20 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

plt.plot(figsize=(6, 4))

sns.lineplot(
    data=df_test,
    x='Date',
    y='Adj Close in 60 Days',
    alpha=0.5,
    label='Actual Stock Price',
)

sns.lineplot(
    data=df_test,
    x='Date',
    y='Prediction',
    alpha=0.5,
    label='Predicted Stock Price',
)

plt.title('Verizon Stock Price vs. Prediction')

plt.xlim(df_test['Date'].min(), df_test['Date'].max())

plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.2f}"))

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.plot(figsize=(6, 4))

sns.lineplot(
    data=df_test,
    x='Date',
    y='Adj Close in 60 Days',
    label='Actual Stock Price',
)

plt.fill_between(
    x=df_test['Date'],
    y1=df_test['Lower Bound Prediction'],
    y2=df_test['Upper Bound Prediction'],
    alpha=0.25,
    color=sns.color_palette()[1],
    label=r'10% to 90% Predicted Price Interval',
)

plt.title('Verizon Stock Price vs. Probabilistic Prediction')

plt.xlim(df_test['Date'].min(), df_test['Date'].max())

plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.2f}"))

plt.legend(loc='upper left')

plt.show()
